# %%
# dataset source: https://www.kaggle.com/datasets/nitindatta/finance-data?select=Finance_data.csv

# %%
# !pip install numpy

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.set_style("darkgrid")

# %%
df = pd.read_csv("D:\Mente\Programacao\Python\Financial Analysis\Projeto1\Finance_data.csv")

# %%
df.head()
# Out:
#    gender  age Investment_Avenues  Mutual_Funds  Equity_Market  Debentures  \
# 0  Female   34                Yes             1              2           5
# 1  Female   23                Yes             4              3           2
# 2    Male   30                Yes             3              6           4
# 3    Male   22                Yes             2              1           3
# 4  Female   24                 No             2              1           3
#
#    Government_Bonds  Fixed_Deposits  PPF  Gold  ...           Duration  \
# 0                 3               7    6     4  ...          1-3 years
# 1                 1               5    6     7  ...  More than 5 years
# 2                 2               5    1     7  ...          3-5 years
# 3                 7               6    4     5  ...   Less than 1 year
# 4                 6               4    5     7  ...   Less than 1 year
#
#   Invest_Monitor   Expect       Avenue What are your savings objectives?  \
# 0        Monthly  20%-30%  Mutual Fund                   Retirement Plan
# 1         Weekly  20%-30%  Mutual Fund                       Health Care
# 2          Daily  20%-30%       Equity                   Retirement Plan
# 3          Daily  10%-20%       Equity                   Retirement Plan
# 4          Daily  20%-30%       Equity                   Retirement Plan
#
#           Reason_Equity         Reason_Mutual     Reason_Bonds  \
# 0  Capital Appreciation        Better Returns  Safe Investment
# 1              Dividend        Better Returns  Safe Investment
# 2  Capital Appreciation          Tax Benefits  Assured Returns
# 3              Dividend  Fund Diversification   Tax Incentives
# 4  Capital Appreciation        Better Returns  Safe Investment
#
#              Reason_FD                    Source
# 0        Fixed Returns  Newspapers and Magazines
# 1  High Interest Rates     Financial Consultants
# 2        Fixed Returns                Television
# 3  High Interest Rates                  Internet
# 4            Risk Free                  Internet
#
# [5 rows x 24 columns]

# %%
condicoes = [(df['Mutual_Funds'] == 1), 
             (df['Equity_Market'] == 1), 
             (df['Debentures'] == 1),
             (df['Government_Bonds'] == 1),
             (df['Fixed_Deposits'] == 1),
             (df['PPF'] == 1),
             (df['Gold'] == 1)]
opcoes = ['Mutual_Funds', 'Equity_Market', 'Debentures', 'Government_Bonds', 'Fixed_Deposits', 'PPF', 'Gold']
df['Preferred_Inv_Option'] = np.select(condicoes, opcoes)
df
# Out:
#     gender  age Investment_Avenues  Mutual_Funds  Equity_Market  Debentures  \
# 0   Female   34                Yes             1              2           5
# 1   Female   23                Yes             4              3           2
# 2     Male   30                Yes             3              6           4
# 3     Male   22                Yes             2              1           3
# 4   Female   24                 No             2              1           3
# 5   Female   24                 No             7              5           4
# 6   Female   27                Yes             3              6           4
# 7     Male   21                Yes             2              3           7
# 8     Male   35                Yes             2              4           7
# 9     Male   31                Yes             1              3           7
# 10  Female   35                Yes             2              4           7
# 11    Male   29                Yes             2              5           7
# 12  Female   21                 No             1              2           3
# 13  Female   28                Yes             2              3           7
# 14  Female   25                Yes             2              3           7
# 15    Male   27                Yes             2              3           7
# 16  Female   28                Yes             3              2           7
# 17    Male   27                Yes             3              2           7
# 18    Male   29                Yes             3              2           7
# 19    Male   26                Yes             3              4           6
# 20    Male   29                Yes             2              4           7
# 21  Female   24                Yes             2              4           5
# 22    Male   27                Yes             3              4           6
# 23    Male   25                Yes             2              4           6
# 24  Female   26                Yes             2              3           7
# 25  Female   32                Yes             3              4           7
# 26    Male   26                Yes             3              4           6
# 27    Male   31                Yes             2              3           7
# 28    Male   29                Yes             2              3           6
# 29  Female   34                Yes             5              4           3
# 30    Male   27                Yes             4              5           1
# 31  Female   31                Yes             2              4           7
# 32    Male   27                Yes             2              4           7
# 33    Male   26                Yes             2              3           6
# 34    Male   27                Yes             2              3           6
# 35    Male   30                Yes             1              4           6
# 36    Male   30                Yes             2              4           7
# 37    Male   25                Yes             5              4           7
# 38    Male   31                Yes             2              4           7
# 39    Male   29                Yes             4              3           5
#
#     Government_Bonds  Fixed_Deposits  PPF  Gold  ... Invest_Monitor   Expect  \
# 0                  3               7    6     4  ...        Monthly  20%-30%
# 1                  1               5    6     7  ...         Weekly  20%-30%
# 2                  2               5    1     7  ...          Daily  20%-30%
# 3                  7               6    4     5  ...          Daily  10%-20%
# 4                  6               4    5     7  ...          Daily  20%-30%
# 5                  6               3    1     2  ...          Daily  30%-40%
# 6                  2               5    1     7  ...        Monthly  20%-30%
# 7                  4               6    1     5  ...        Monthly  20%-30%
# 8                  5               3    1     6  ...         Weekly  20%-30%
# 9                  4               5    2     6  ...        Monthly  30%-40%
# 10                 5               3    1     6  ...        Monthly  20%-30%
# 11                 6               3    1     4  ...        Monthly  20%-30%
# 12                 4               5    6     7  ...         Weekly  20%-30%
# 13                 4               5    1     6  ...        Monthly  20%-30%
# 14                 5               4    1     6  ...        Monthly  20%-30%
# 15                 5               4    1     6  ...        Monthly  20%-30%
# 16                 5               4    1     6  ...        Monthly  20%-30%
# 17                 4               5    1     6  ...        Monthly  20%-30%
# 18                 4               5    1     6  ...        Monthly  20%-30%
# 19                 5               1    2     7  ...        Monthly  20%-30%
# 20                 5               3    1     6  ...         Weekly  20%-30%
# 21                 6               3    1     7  ...        Monthly  20%-30%
# 22                 5               2    1     7  ...        Monthly  20%-30%
# 23                 5               3    1     7  ...         Weekly  20%-30%
# 24                 5               4    1     6  ...        Monthly  30%-40%
# 25                 5               1    2     6  ...        Monthly  20%-30%
# 26                 5               1    2     7  ...        Monthly  20%-30%
# 27                 6               4    1     5  ...        Monthly  20%-30%
# 28                 5               1    4     7  ...        Monthly  20%-30%
# 29                 2               7    1     6  ...        Monthly  10%-20%
# 30                 2               7    3     6  ...        Monthly  10%-20%
# 31                 6               3    1     5  ...        Monthly  20%-30%
# 32                 5               1    3     6  ...        Monthly  30%-40%
# 33                 4               1    5     7  ...        Monthly  20%-30%
# 34                 5               4    1     7  ...         Weekly  20%-30%
# 35                 5               3    2     7  ...        Monthly  20%-30%
# 36                 5               1    3     6  ...        Monthly  20%-30%
# 37                 6               1    2     3  ...        Monthly  30%-40%
# 38                 5               3    1     6  ...         Weekly  20%-30%
# 39                 7               2    1     6  ...        Monthly  20%-30%
#
#                    Avenue What are your savings objectives?  \
# 0             Mutual Fund                   Retirement Plan
# 1             Mutual Fund                       Health Care
# 2                  Equity                   Retirement Plan
# 3                  Equity                   Retirement Plan
# 4                  Equity                   Retirement Plan
# 5             Mutual Fund                   Retirement Plan
# 6                  Equity                   Retirement Plan
# 7             Mutual Fund                   Retirement Plan
# 8                  Equity                   Retirement Plan
# 9          Fixed Deposits                   Retirement Plan
# 10            Mutual Fund                   Retirement Plan
# 11            Mutual Fund                   Retirement Plan
# 12            Mutual Fund                         Education
# 13            Mutual Fund                   Retirement Plan
# 14         Fixed Deposits                       Health Care
# 15            Mutual Fund                       Health Care
# 16         Fixed Deposits                       Health Care
# 17            Mutual Fund                   Retirement Plan
# 18            Mutual Fund                   Retirement Plan
# 19         Fixed Deposits                       Health Care
# 20            Mutual Fund                   Retirement Plan
# 21                 Equity                       Health Care
# 22            Mutual Fund                   Retirement Plan
# 23  Public Provident Fund                       Health Care
# 24  Public Provident Fund                   Retirement Plan
# 25            Mutual Fund                   Retirement Plan
# 26            Mutual Fund                   Retirement Plan
# 27         Fixed Deposits                       Health Care
# 28                 Equity                   Retirement Plan
# 29            Mutual Fund                   Retirement Plan
# 30            Mutual Fund                         Education
# 31         Fixed Deposits                   Retirement Plan
# 32                 Equity                       Health Care
# 33         Fixed Deposits                         Education
# 34            Mutual Fund                       Health Care
# 35         Fixed Deposits                       Health Care
# 36                 Equity                   Retirement Plan
# 37  Public Provident Fund                       Health Care
# 38                 Equity                       Health Care
# 39         Fixed Deposits                   Retirement Plan
#
#            Reason_Equity         Reason_Mutual     Reason_Bonds  \
# 0   Capital Appreciation        Better Returns  Safe Investment
# 1               Dividend        Better Returns  Safe Investment
# 2   Capital Appreciation          Tax Benefits  Assured Returns
# 3               Dividend  Fund Diversification   Tax Incentives
# 4   Capital Appreciation        Better Returns  Safe Investment
# 5              Liquidity  Fund Diversification  Safe Investment
# 6   Capital Appreciation        Better Returns  Assured Returns
# 7   Capital Appreciation        Better Returns  Assured Returns
# 8   Capital Appreciation  Fund Diversification  Safe Investment
# 9   Capital Appreciation  Fund Diversification  Assured Returns
# 10  Capital Appreciation        Better Returns  Assured Returns
# 11  Capital Appreciation  Fund Diversification  Assured Returns
# 12              Dividend        Better Returns  Safe Investment
# 13  Capital Appreciation  Fund Diversification  Assured Returns
# 14              Dividend        Better Returns  Assured Returns
# 15  Capital Appreciation  Fund Diversification  Assured Returns
# 16  Capital Appreciation  Fund Diversification  Assured Returns
# 17  Capital Appreciation        Better Returns  Assured Returns
# 18  Capital Appreciation        Better Returns  Assured Returns
# 19  Capital Appreciation  Fund Diversification  Assured Returns
# 20  Capital Appreciation        Better Returns  Assured Returns
# 21  Capital Appreciation        Better Returns  Assured Returns
# 22  Capital Appreciation        Better Returns  Assured Returns
# 23             Liquidity        Better Returns  Assured Returns
# 24  Capital Appreciation        Better Returns  Assured Returns
# 25  Capital Appreciation        Better Returns  Assured Returns
# 26              Dividend  Fund Diversification  Assured Returns
# 27  Capital Appreciation  Fund Diversification  Safe Investment
# 28  Capital Appreciation        Better Returns  Assured Returns
# 29  Capital Appreciation          Tax Benefits  Safe Investment
# 30  Capital Appreciation          Tax Benefits  Safe Investment
# 31  Capital Appreciation        Better Returns  Assured Returns
# 32  Capital Appreciation  Fund Diversification  Assured Returns
# 33              Dividend        Better Returns  Safe Investment
# 34  Capital Appreciation        Better Returns  Safe Investment
# 35  Capital Appreciation        Better Returns  Assured Returns
# 36  Capital Appreciation        Better Returns  Assured Returns
# 37  Capital Appreciation        Better Returns  Safe Investment
# 38              Dividend  Fund Diversification  Assured Returns
# 39              Dividend        Better Returns  Safe Investment
#
#               Reason_FD                    Source Preferred_Inv_Option
# 0         Fixed Returns  Newspapers and Magazines         Mutual_Funds
# 1   High Interest Rates     Financial Consultants     Government_Bonds
# 2         Fixed Returns                Television                  PPF
# 3   High Interest Rates                  Internet        Equity_Market
# 4             Risk Free                  Internet        Equity_Market
# 5             Risk Free                  Internet                  PPF
# 6   High Interest Rates     Financial Consultants                  PPF
# 7             Risk Free  Newspapers and Magazines                  PPF
# 8         Fixed Returns                Television                  PPF
# 9         Fixed Returns  Newspapers and Magazines         Mutual_Funds
# 10            Risk Free     Financial Consultants                  PPF
# 11        Fixed Returns     Financial Consultants                  PPF
# 12            Risk Free                  Internet         Mutual_Funds
# 13            Risk Free  Newspapers and Magazines                  PPF
# 14            Risk Free     Financial Consultants                  PPF
# 15            Risk Free  Newspapers and Magazines                  PPF
# 16            Risk Free                Television                  PPF
# 17            Risk Free     Financial Consultants                  PPF
# 18            Risk Free  Newspapers and Magazines                  PPF
# 19            Risk Free  Newspapers and Magazines       Fixed_Deposits
# 20        Fixed Returns     Financial Consultants                  PPF
# 21            Risk Free  Newspapers and Magazines                  PPF
# 22            Risk Free     Financial Consultants                  PPF
# 23            Risk Free     Financial Consultants                  PPF
# 24            Risk Free  Newspapers and Magazines                  PPF
# 25        Fixed Returns     Financial Consultants       Fixed_Deposits
# 26        Fixed Returns     Financial Consultants       Fixed_Deposits
# 27        Fixed Returns                Television                  PPF
# 28            Risk Free                Television       Fixed_Deposits
# 29        Fixed Returns  Newspapers and Magazines                  PPF
# 30        Fixed Returns                Television           Debentures
# 31        Fixed Returns     Financial Consultants                  PPF
# 32        Fixed Returns  Newspapers and Magazines       Fixed_Deposits
# 33            Risk Free  Newspapers and Magazines       Fixed_Deposits
# 34        Fixed Returns     Financial Consultants                  PPF
# 35        Fixed Returns     Financial Consultants         Mutual_Funds
# 36            Risk Free  Newspapers and Magazines       Fixed_Deposits
# 37        Fixed Returns     Financial Consultants       Fixed_Deposits
# 38        Fixed Returns  Newspapers and Magazines                  PPF
# 39        Fixed Returns     Financial Consultants                  PPF
#
# [40 rows x 25 columns]

# %%
data = df["gender"].value_counts()
colors = sns.color_palette("Set3")
plt.pie(data, labels=data.index, autopct='%.0f%%', colors=colors, shadow=True, explode=[0.05,0.05])
plt.title("GENDER OF THE PARTICIPANTS", fontsize=10)
plt.show()

# %%
graph2 = sns.countplot(x="age", data=df, palette="Set2", linewidth=1, edgecolor="black")
for label in graph2.containers:
    graph2.bar_label(label, padding=3)
graph2.set(ylabel=None,xlabel=None,yticklabels=[])
plt.title("AGE OF THE PARTICIPANTS", fontsize=10)
plt.show()

# %%
plt.figure(figsize=(17,7))
graph3=plt.subplot(1,2,1)
sns.countplot(x=df["gender"], hue=df["Investment_Avenues"], palette="summer", linewidth=3, edgecolor="white")
for label in graph3.containers:
    graph3.bar_label(label, size=13, padding=2)
graph3.set(ylabel=None,xlabel=None,yticklabels=[])
graph3.xaxis.set_tick_params(labelsize=12)
plt.legend(fontsize=14)
plt.title("INVESTMENT AVENUE", fontsize=12)

graph4=plt.subplot(1,2,2)
sns.countplot(x=df['gender'],hue=df["Stock_Marktet"], palette="hot", linewidth=3, edgecolor="white")
for label in graph4.containers:
    graph4.bar_label(label, size=13, padding=2)
graph4.set(ylabel=None,xlabel=None,yticklabels=[])
graph4.xaxis.set_tick_params(labelsize=12)
plt.legend(fontsize=14)
plt.title("STOCK MARKET", fontsize=12)

plt.show()

# %%
graph5=sns.countplot(x=df["Factor"], palette="coolwarm", linewidth=2, edgecolor="black")
for label in graph5.containers:
    graph5.bar_label(label)
graph5.set(ylabel=None,xlabel=None,yticklabels=[])
plt.title("FACTOR CONSIDERED FOR INVESTING", fontsize=12)
plt.show()

# %%
plt.figure(figsize=(10,5))
graph6=sns.pointplot(x="Purpose", y="age", data=df, linestyles="--", capsize=.3, color="Blue")
plt.title("INVESTMENT OBJECTIVE")
graph6.set(xlabel=None)
graph6.set_ylabel("Age",size=10)
graph6.xaxis.set_tick_params(labelsize=10)
graph6.yaxis.set_tick_params(labelsize=10)
plt.show()

# %%
plt.figure(figsize=(15,5))
graph7=plt.subplot(1,2,1)
sns.countplot(y=df["Duration"], hue=df["gender"], palette="viridis", linewidth=2, edgecolor="black")
for label in graph7.containers:
    graph7.bar_label(label, size=12, padding=3)
graph7.set(ylabel=None,xlabel=None,xticklabels=[])
graph7.yaxis.set_tick_params(labelsize=13)
plt.legend(fontsize=12)
plt.title("DURATION", fontsize=15)

plt.subplot(1,2,2)
graph8=sns.countplot(y=df["Invest_Monitor"], hue=df["gender"], palette="seismic", linewidth=2, edgecolor="black")
for label in graph8.containers:
    graph8.bar_label(label, size=12, padding=3)
graph8.set(ylabel=None,xlabel=None,xticklabels=[])
graph8.yaxis.set_tick_params(labelsize=13)
plt.legend(fontsize=12)
plt.title("MONITORIZATION FREQUENCY", fontsize=15)

plt.show()

# %%
plt.figure(figsize=(9,5))
graph9 = sns.countplot(y="Preferred_Inv_Option", data=df, palette="Set2", linewidth=1, edgecolor="black",
                      order = df['Preferred_Inv_Option'].value_counts().index)
for label in graph9.containers:
    graph9.bar_label(label, padding=3)
graph9.set(ylabel=None,xlabel=None,xticklabels=[])
graph9.xaxis.set_tick_params(labelsize=10)
plt.title("INVESTMENT OPTIONS")
plt.show()

# %%
plt.figure(figsize=(18,8))
graph10=sns.countplot(x=df["Preferred_Inv_Option"], hue=df["gender"], palette="viridis", linewidth=2, edgecolor="black")
for label in graph10.containers:
    graph10.bar_label(label, size=12, padding=3)
graph10.set(ylabel=None,xlabel=None,yticklabels=[])
graph10.xaxis.set_tick_params(labelsize=13)
plt.title("FAVOURITE INVESTMENT OPTION")
plt.legend(fontsize=12)
plt.show()
